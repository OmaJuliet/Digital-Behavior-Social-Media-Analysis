# %%
import pandas as pd
import numpy as np

# Load the dataset (replace the path with your file path)
df = pd.read_csv('social_media_entertainment_data.csv')

# Display the first few rows
print(df.head())

# Get an overview of the dataset
print(df.info())
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# 3          YouTube                        3.69
# 4           TikTok                        3.97
#
#    Daily Video Content Time (hrs)  ...  Ad Interaction Count  \
# 0                            5.43  ...                    20
# 1                            4.22  ...                    26
# 2                            1.09  ...                    47
# 3                            4.80  ...                    22
# 4                            2.74  ...                    42
#
#   Time on Educational Platforms (hrs) Parental Status  \
# 0                                4.11             Yes
# 1                                4.59             Yes
# 2                                0.66             Yes
# 3                                3.44             Yes
# 4                                4.14             Yes
#
#    Tech Savviness Level (scale 1-10) Preferred Device for Entertainment  \
# 0                                  9                             Tablet
# 1                                  9                                 PC
# 2                                  9                             Tablet
# 3                                  7                             Tablet
# 4                                  7                           Smart TV
#
#    Data Plan Used  Digital Well-being Awareness  Sleep Quality (scale 1-10)  \
# 0            50GB                      Moderate                           7
# 1            10GB                           Low                           8
# 2            10GB                          High                           5
# 3            10GB                           Low                           9
# 4       Unlimited                           Low                           5
#
#    Social Isolation Feeling (scale 1-10)  \
# 0                                      8
# 1                                      2
# 2                                      3
# 3                                      9
# 4                                      9
#
#    Monthly Expenditure on Entertainment (USD)
# 0                                       33.04
# 1                                      497.78
# 2                                       71.72
# 3                                      129.62
# 4                                       35.90
#
# [5 rows x 40 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 40 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   User ID                                     300000 non-null  int64
#  1   Age                                         300000 non-null  int64
#  2   Gender                                      300000 non-null  object
#  3   Country                                     300000 non-null  object
#  4   Daily Social Media Time (hrs)               300000 non-null  float64
#  5   Daily Entertainment Time (hrs)              300000 non-null  float64
#  6   Social Media Platforms Used                 300000 non-null  int64
#  7   Primary Platform                            300000 non-null  object
#  8   Daily Messaging Time (hrs)                  300000 non-null  float64
#  9   Daily Video Content Time (hrs)              300000 non-null  float64
#  10  Daily Gaming Time (hrs)                     300000 non-null  float64
#  11  Occupation                                  300000 non-null  object
#  12  Marital Status                              300000 non-null  object
#  13  Monthly Income (USD)                        300000 non-null  float64
#  14  Device Type                                 300000 non-null  object
#  15  Internet Speed (Mbps)                       300000 non-null  float64
#  16  Subscription Platforms                      300000 non-null  int64
#  17  Average Sleep Time (hrs)                    300000 non-null  float64
#  18  Physical Activity Time (hrs)                300000 non-null  float64
#  19  Reading Time (hrs)                          300000 non-null  float64
#  20  Work/Study Time (hrs)                       300000 non-null  float64
#  21  Screen Time (hrs)                           300000 non-null  float64
#  22  Notifications Received Daily                300000 non-null  int64
#  23  Daily Music Listening Time (hrs)            300000 non-null  float64
#  24  Preferred Content Type                      300000 non-null  object
#  25  Primary Social Media Goal                   300000 non-null  object
#  26  Preferred Entertainment Platform            300000 non-null  object
#  27  Time Spent in Online Communities (hrs)      300000 non-null  float64
#  28  Social Media Fatigue Level (scale 1-10)     300000 non-null  int64
#  29  News Consumption Time (hrs)                 300000 non-null  float64
#  30  Ad Interaction Count                        300000 non-null  int64
#  31  Time on Educational Platforms (hrs)         300000 non-null  float64
#  32  Parental Status                             300000 non-null  object
#  33  Tech Savviness Level (scale 1-10)           300000 non-null  int64
#  34  Preferred Device for Entertainment          300000 non-null  object
#  35  Data Plan Used                              300000 non-null  object
#  36  Digital Well-being Awareness                300000 non-null  object
#  37  Sleep Quality (scale 1-10)                  300000 non-null  int64
#  38  Social Isolation Feeling (scale 1-10)       300000 non-null  int64
#  39  Monthly Expenditure on Entertainment (USD)  300000 non-null  float64
# dtypes: float64(17), int64(10), object(13)
# memory usage: 91.6+ MB
# None

# %%
# Step 1: Check for missing values and duplicates

# Check for missing values
missing_values = df.isnull().sum()

# Check for duplicates
duplicates = df[df.duplicated()]

print(f"Missing Values:\n{missing_values}")
print(f"Duplicate Rows:\n{duplicates}")
# Out:
# Missing Values:
# User ID                                       0
# Age                                           0
# Gender                                        0
# Country                                       0
# Daily Social Media Time (hrs)                 0
# Daily Entertainment Time (hrs)                0
# Social Media Platforms Used                   0
# Primary Platform                              0
# Daily Messaging Time (hrs)                    0
# Daily Video Content Time (hrs)                0
# Daily Gaming Time (hrs)                       0
# Occupation                                    0
# Marital Status                                0
# Monthly Income (USD)                          0
# Device Type                                   0
# Internet Speed (Mbps)                         0
# Subscription Platforms                        0
# Average Sleep Time (hrs)                      0
# Physical Activity Time (hrs)                  0
# Reading Time (hrs)                            0
# Work/Study Time (hrs)                         0
# Screen Time (hrs)                             0
# Notifications Received Daily                  0
# Daily Music Listening Time (hrs)              0
# Preferred Content Type                        0
# Primary Social Media Goal                     0
# Preferred Entertainment Platform              0
# Time Spent in Online Communities (hrs)        0
# Social Media Fatigue Level (scale 1-10)       0
# News Consumption Time (hrs)                   0
# Ad Interaction Count                          0
# Time on Educational Platforms (hrs)           0
# Parental Status                               0
# Tech Savviness Level (scale 1-10)             0
# Preferred Device for Entertainment            0
# Data Plan Used                                0
# Digital Well-being Awareness                  0
# Sleep Quality (scale 1-10)                    0
# Social Isolation Feeling (scale 1-10)         0
# Monthly Expenditure on Entertainment (USD)    0
# dtype: int64
# Duplicate Rows:
# Empty DataFrame
# Columns: [User ID, Age, Gender, Country, Daily Social Media Time (hrs), Daily Entertainment Time (hrs), Social Media Platforms Used, Primary Platform, Daily Messaging Time (hrs), Daily Video Content Time (hrs), Daily Gaming Time (hrs), Occupation, Marital Status, Monthly Income (USD), Device Type, Internet Speed (Mbps), Subscription Platforms, Average Sleep Time (hrs), Physical Activity Time (hrs), Reading Time (hrs), Work/Study Time (hrs), Screen Time (hrs), Notifications Received Daily, Daily Music Listening Time (hrs), Preferred Content Type, Primary Social Media Goal, Preferred Entertainment Platform, Time Spent in Online Communities (hrs), Social Media Fatigue Level (scale 1-10), News Consumption Time (hrs), Ad Interaction Count, Time on Educational Platforms (hrs), Parental Status, Tech Savviness Level (scale 1-10), Preferred Device for Entertainment, Data Plan Used, Digital Well-being Awareness, Sleep Quality (scale 1-10), Social Isolation Feeling (scale 1-10), Monthly Expenditure on Entertainment (USD)]
# Index: []
#
# [0 rows x 40 columns]

# %%
# Step 2: Rename columns for consistency

df.rename(columns={
    'Monthly Expenditure on Entertainment (USD)': 'Monthly_Expenditure_Entertainment',
    'Primary Social Media Goal': 'Primary_Social_Media_Goal',
    'Social Media Platforms Used': 'Social_Media_Platforms_Used',
    'Preferred Device for Entertainment': 'Preferred_Device_Entertainment',
    'Time on Educational Platforms (hrs)': 'Time_Educational_Platforms',
    'Physical Activity Time (hrs)': 'Physical_Activity_Time',
    'Work/Study Time (hrs)': 'Work_Study_Time',
    'Screen Time (hrs)': 'Screen_Time',
    'Marital Status': 'Marital_Status',
    'Notifications Received Daily': 'Notifications_Received',
    'Social Media Fatigue Level (scale 1-10)': 'Social_Media_Fatigue',
    'Tech Savviness Level (scale 1-10)': 'Tech_Savviness_Level',
    'Social Isolation Feeling (scale 1-10)': 'Social_Isolation_Feelings',
    'Average Sleep Time (hrs)': 'Average_Sleep_Time',
    'Daily Social Media Time (hrs)': 'Daily_Social_Media_Time',
    'Daily Entertainment Time (hrs)': 'Daily_Entertainment_Time',
    'Daily Gaming Time (hrs)': 'Daily_Gaming_Time',
    'Daily Video Content Time (hrs)': 'Daily_Video_Content_Time',
    'Daily Messaging Time (hrs)': 'Daily_Messaging_Time',
    'User ID': 'User_ID',
    'Subscription Platforms': 'Subscription_Platforms',
    'Device Type': 'Device_Type',
    'Primary Platform': 'Primary_Platform',
    'Monthly Income (USD)': 'Monthly_Income',
    'Reading Time (hrs)': 'Reading_Time',
    'Time Spent in Online Communities (hrs)': 'Time_Online_Communities',
    'Ad Interaction Count': 'Ad_Interaction_Count',
    'News Consumption Time (hrs)': 'News_Consumption_Time',
    'Internet Speed (Mbps)': 'Internet_Speed',
    'Daily Music Listening Time (hrs)': 'Daily_Music_Listening_Time',
    'Preferred Content Type': 'Preferred_Content_Type',
    'Preferred Entertainment Platform': 'Preferred_Entertainment_Platform',
    'Parental Status': 'Parental_Status',
    'Data Plan Used': 'Data_Plan_Used',
    'Digital Well-being Awareness': 'Digital_Well_Being_Awareness',
    'Sleep Quality (scale 1-10)': 'Sleep_Quality',
}, inplace=True)

# %%
print(df.head())
# Out:
#    User_ID  Age  Gender  Country  Daily_Social_Media_Time  \
# 0        1   32   Other  Germany                     4.35
# 1        2   62   Other    India                     4.96
# 2        3   51  Female      USA                     6.78
# 3        4   44  Female    India                     5.06
# 4        5   21   Other  Germany                     2.57
#
#    Daily_Entertainment_Time  Social_Media_Platforms_Used Primary_Platform  \
# 0                      4.08                            5           TikTok
# 1                      4.21                            2          YouTube
# 2                      1.77                            4         Facebook
# 3                      9.21                            3          YouTube
# 4                      1.30                            4           TikTok
#
#    Daily_Messaging_Time  Daily_Video_Content_Time  ...  Ad_Interaction_Count  \
# 0                  0.35                      5.43  ...                    20
# 1                  2.55                      4.22  ...                    26
# 2                  2.09                      1.09  ...                    47
# 3                  3.69                      4.80  ...                    22
# 4                  3.97                      2.74  ...                    42
#
#   Time_Educational_Platforms Parental_Status  Tech_Savviness_Level  \
# 0                       4.11             Yes                     9
# 1                       4.59             Yes                     9
# 2                       0.66             Yes                     9
# 3                       3.44             Yes                     7
# 4                       4.14             Yes                     7
#
#   Preferred_Device_Entertainment  Data_Plan_Used  \
# 0                         Tablet            50GB
# 1                             PC            10GB
# 2                         Tablet            10GB
# 3                         Tablet            10GB
# 4                       Smart TV       Unlimited
#
#    Digital_Well_Being_Awareness  Sleep_Quality  Social_Isolation_Feelings  \
# 0                      Moderate              7                          8
# 1                           Low              8                          2
# 2                          High              5                          3
# 3                           Low              9                          9
# 4                           Low              5                          9
#
#    Monthly_Expenditure_Entertainment
# 0                              33.04
# 1                             497.78
# 2                              71.72
# 3                             129.62
# 4                              35.90
#
# [5 rows x 40 columns]

# %%
# Step 3: Check and Validate Data Types

print(f"Original Data Types:\n{df.dtypes}")
# Out:
# Original Data Types:
# User_ID                                int64
# Age                                    int64
# Gender                                object
# Country                               object
# Daily_Social_Media_Time              float64
# Daily_Entertainment_Time             float64
# Social_Media_Platforms_Used            int64
# Primary_Platform                      object
# Daily_Messaging_Time                 float64
# Daily_Video_Content_Time             float64
# Daily_Gaming_Time                    float64
# Occupation                            object
# Marital_Status                        object
# Monthly_Income                       float64
# Device_Type                           object
# Internet_Speed                       float64
# Subscription_Platforms                 int64
# Average_Sleep_Time                   float64
# Physical_Activity_Time               float64
# Reading_Time                         float64
# Work_Study_Time                      float64
# Screen_Time                          float64
# Notifications_Received                 int64
# Daily_Music_Listening_Time           float64
# Preferred_Content_Type                object
# Primary_Social_Media_Goal             object
# Preferred_Entertainment_Platform      object
# Time_Online_Communities              float64
# Social_Media_Fatigue                   int64
# News_Consumption_Time                float64
# Ad_Interaction_Count                   int64
# Time_Educational_Platforms           float64
# Parental_Status                       object
# Tech_Savviness_Level                   int64
# Preferred_Device_Entertainment        object
# Data_Plan_Used                        object
# Digital_Well_Being_Awareness          object
# Sleep_Quality                          int64
# Social_Isolation_Feelings              int64
# Monthly_Expenditure_Entertainment    float64
# dtype: object

# %%
# Step 4: Perform Exploratory Data Analysis (EDA)

# Summary statistics for numerical columns
summary_stats = df.describe()

# Count unique values for categorical columns
unique_values = df.select_dtypes(include=['object']).nunique()

print(f"Summary Statistics:\n{summary_stats}")
print(f"Unique Values in Categorical Columns:\n{unique_values}")
# Out:
# Summary Statistics:
#              User_ID            Age  Daily_Social_Media_Time  \
# count  300000.000000  300000.000000            300000.000000
# mean   150000.500000      38.530547                 4.254808
# std     86602.684716      15.005038                 2.165604
# min         1.000000      13.000000                 0.500000
# 25%     75000.750000      26.000000                 2.380000
# 50%    150000.500000      39.000000                 4.260000
# 75%    225000.250000      52.000000                 6.130000
# max    300000.000000      65.000000                 8.000000
#
#        Daily_Entertainment_Time  Social_Media_Platforms_Used  \
# count             300000.000000                300000.000000
# mean                   5.244080                     3.000143
# std                    2.741804                     1.413682
# min                    0.500000                     1.000000
# 25%                    2.870000                     2.000000
# 50%                    5.240000                     3.000000
# 75%                    7.620000                     4.000000
# max                   10.000000                     5.000000
#
#        Daily_Messaging_Time  Daily_Video_Content_Time  Daily_Gaming_Time  \
# count         300000.000000             300000.000000      300000.000000
# mean               2.598320                  3.749153           2.499733
# std                1.385418                  1.877316           1.443159
# min                0.200000                  0.500000           0.000000
# 25%                1.400000                  2.120000           1.250000
# 50%                2.600000                  3.750000           2.500000
# 75%                3.790000                  5.370000           3.750000
# max                5.000000                  7.000000           5.000000
#
#        Monthly_Income  Internet_Speed  ...  Daily_Music_Listening_Time  \
# count   300000.000000   300000.000000  ...               300000.000000
# mean      5256.918847       52.481476  ...                    3.246100
# std       2741.260952       27.394893  ...                    1.587595
# min        500.010000        5.000000  ...                    0.500000
# 25%       2883.817500       28.730000  ...                    1.870000
# 50%       5259.010000       52.470000  ...                    3.240000
# 75%       7630.525000       76.210000  ...                    4.620000
# max       9999.930000      100.000000  ...                    6.000000
#
#        Time_Online_Communities  Social_Media_Fatigue  News_Consumption_Time  \
# count            300000.000000         300000.000000          300000.000000
# mean                  2.000779              5.003780               1.500046
# std                   1.154578              2.580703               0.866270
# min                   0.000000              1.000000               0.000000
# 25%                   1.000000              3.000000               0.750000
# 50%                   2.000000              5.000000               1.500000
# 75%                   3.000000              7.000000               2.250000
# max                   4.000000             10.000000               3.000000
#
#        Ad_Interaction_Count  Time_Educational_Platforms  Tech_Savviness_Level  \
# count          300000.00000               300000.000000         300000.000000
# mean               24.48071                    2.500206              5.009983
# std                14.42579                    1.441704              2.584137
# min                 0.00000                    0.000000              1.000000
# 25%                12.00000                    1.250000              3.000000
# 50%                24.00000                    2.500000              5.000000
# 75%                37.00000                    3.750000              7.000000
# max                50.00000                    5.000000             10.000000
#
#        Sleep_Quality  Social_Isolation_Feelings  \
# count  300000.000000              300000.000000
# mean        5.006430                   5.004487
# std         2.579214                   2.583077
# min         1.000000                   1.000000
# 25%         3.000000                   3.000000
# 50%         5.000000                   5.000000
# 75%         7.000000                   7.000000
# max        10.000000                  10.000000
#
#        Monthly_Expenditure_Entertainment
# count                      300000.000000
# mean                          249.670252
# std                           144.372234
# min                             0.000000
# 25%                           124.350000
# 50%                           249.900000
# 75%                           374.370000
# max                           500.000000
#
# [8 rows x 27 columns]
# Unique Values in Categorical Columns:
# Gender                              3
# Country                             6
# Primary_Platform                    5
# Occupation                          4
# Marital_Status                      4
# Device_Type                         3
# Preferred_Content_Type              4
# Primary_Social_Media_Goal           4
# Preferred_Entertainment_Platform    4
# Parental_Status                     2
# Preferred_Device_Entertainment      4
# Data_Plan_Used                      3
# Digital_Well_Being_Awareness        3
# dtype: int64

# %%
# Step 5: Create new columns for easier analysis

# 1. Online Activity Share (percentage of screen time spent on video, gaming, and messaging)
df['Online_Activity_Share'] = (df['Daily_Video_Content_Time'] + df['Daily_Gaming_Time'] + df['Daily_Messaging_Time']) / df['Screen_Time'] * 100

# 2. High/Low Tech-Savviness (categorize Tech Savviness Level into Low and High)
df['High_Low_Tech_Savviness'] = df['Tech_Savviness_Level'].apply(lambda x: 'High' if x >= 6 else 'Low')

# 3. Work-to-Entertainment Ratio (how much time is spent on work/study vs entertainment)
df['Work_to_Entertainment_Ratio'] = df['Work_Study_Time'] / df['Daily_Entertainment_Time']

# View the new columns added
print(f"New Columns:\n{df[['Online_Activity_Share', 'High_Low_Tech_Savviness', 'Work_to_Entertainment_Ratio']].head()}")
# Out:
# New Columns:
#    Online_Activity_Share High_Low_Tech_Savviness  Work_to_Entertainment_Ratio
# 0             142.701228                    High                     0.492647
# 1             169.739953                    High                     0.681710
# 2             169.887640                    High                     2.209040
# 3             115.839861                    High                     0.206298
# 4             155.602241                    High                     2.053846

# %%
df.drop(columns=['Online_Activity_Share'], inplace=True)

# %%
print(df.head())
# Out:
#    User_ID  Age  Gender  Country  Daily_Social_Media_Time  \
# 0        1   32   Other  Germany                     4.35
# 1        2   62   Other    India                     4.96
# 2        3   51  Female      USA                     6.78
# 3        4   44  Female    India                     5.06
# 4        5   21   Other  Germany                     2.57
#
#    Daily_Entertainment_Time  Social_Media_Platforms_Used Primary_Platform  \
# 0                      4.08                            5           TikTok
# 1                      4.21                            2          YouTube
# 2                      1.77                            4         Facebook
# 3                      9.21                            3          YouTube
# 4                      1.30                            4           TikTok
#
#    Daily_Messaging_Time  Daily_Video_Content_Time  ...  Parental_Status  \
# 0                  0.35                      5.43  ...              Yes
# 1                  2.55                      4.22  ...              Yes
# 2                  2.09                      1.09  ...              Yes
# 3                  3.69                      4.80  ...              Yes
# 4                  3.97                      2.74  ...              Yes
#
#   Tech_Savviness_Level Preferred_Device_Entertainment  Data_Plan_Used  \
# 0                    9                         Tablet            50GB
# 1                    9                             PC            10GB
# 2                    9                         Tablet            10GB
# 3                    7                         Tablet            10GB
# 4                    7                       Smart TV       Unlimited
#
#   Digital_Well_Being_Awareness  Sleep_Quality  Social_Isolation_Feelings  \
# 0                     Moderate              7                          8
# 1                          Low              8                          2
# 2                         High              5                          3
# 3                          Low              9                          9
# 4                          Low              5                          9
#
#    Monthly_Expenditure_Entertainment  High_Low_Tech_Savviness  \
# 0                              33.04                     High
# 1                             497.78                     High
# 2                              71.72                     High
# 3                             129.62                     High
# 4                              35.90                     High
#
#    Work_to_Entertainment_Ratio
# 0                     0.492647
# 1                     0.681710
# 2                     2.209040
# 3                     0.206298
# 4                     2.053846
#
# [5 rows x 42 columns]

# %%
# Step 6: Check for missing values after transformations

missing_values_after_transformation = df.isnull().sum()
print(f"Missing Values After Transformation:\n{missing_values_after_transformation}")
# Out:
# Missing Values After Transformation:
# User_ID                              0
# Age                                  0
# Gender                               0
# Country                              0
# Daily_Social_Media_Time              0
# Daily_Entertainment_Time             0
# Social_Media_Platforms_Used          0
# Primary_Platform                     0
# Daily_Messaging_Time                 0
# Daily_Video_Content_Time             0
# Daily_Gaming_Time                    0
# Occupation                           0
# Marital_Status                       0
# Monthly_Income                       0
# Device_Type                          0
# Internet_Speed                       0
# Subscription_Platforms               0
# Average_Sleep_Time                   0
# Physical_Activity_Time               0
# Reading_Time                         0
# Work_Study_Time                      0
# Screen_Time                          0
# Notifications_Received               0
# Daily_Music_Listening_Time           0
# Preferred_Content_Type               0
# Primary_Social_Media_Goal            0
# Preferred_Entertainment_Platform     0
# Time_Online_Communities              0
# Social_Media_Fatigue                 0
# News_Consumption_Time                0
# Ad_Interaction_Count                 0
# Time_Educational_Platforms           0
# Parental_Status                      0
# Tech_Savviness_Level                 0
# Preferred_Device_Entertainment       0
# Data_Plan_Used                       0
# Digital_Well_Being_Awareness         0
# Sleep_Quality                        0
# Social_Isolation_Feelings            0
# Monthly_Expenditure_Entertainment    0
# High_Low_Tech_Savviness              0
# Work_to_Entertainment_Ratio          0
# dtype: int64

# %%
# Save the cleaned dataframe
df.to_csv('cleaned_social_media_dataset.csv', index=False)
